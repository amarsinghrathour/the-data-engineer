# %% [markdown]
# # Data Quality in ETL Pipelines

# %% [markdown]
# ## Integrate into ETL
#
# ```python
# def transform_with_validation(data):
#     valid = []
#
#     for d in data:
#         if validate_record(d):
#             valid.append(d)
#
#     return valid
# ```

# %% [markdown]
# ## Reject Bad Data
#
# ```python
# def load_safe(data):
#     if not data:
#         raise Exception("No valid data to load")
#
#     load(data)
# ```

# %% [markdown]
# ## Add Metrics
#
# ```python
# print("Total:", len(data))
# print("Valid:", len(valid))
# print("Rejected:", len(data) - len(valid))
# ```

# %% [markdown]
# ## Practice
#
# 1. Add rejection percentage metric.
# 2. Fail pipeline if rejection rate is above threshold.
# 3. Export quality metrics for monitoring.

# %% [markdown]
# ## Assignment
#
# Integrate validation + safe load into one ETL run function and print quality metrics each run.

# %% [markdown]
# ## Interview Questions
#
# 1. How do you integrate data quality in ETL?
# 2. Why fail fast on empty valid datasets?
# 3. Which quality metrics matter most?
# 4. How do you monitor quality trends over time?

# %% [markdown]
# ## Your tasks
#
# - [ ] Add validation into transform stage.
# - [ ] Add `load_safe()` guard before load.
# - [ ] Print and track total/valid/rejected metrics.
