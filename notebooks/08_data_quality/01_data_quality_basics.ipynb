# %% [markdown]
# # Data Quality in Data Engineering

# %% [markdown]
# ## Why This Matters
#
# Bad data leads to bad decisions.
#
# Examples:
# - Missing values
# - Duplicates
# - Invalid formats
#
# 👉 Pipelines must validate data before storing

# %% [markdown]
# ## Common Problems
#
# - Missing fields
# - Wrong data types
# - Duplicate records
# - Outliers
# - Invalid formats

# %% [markdown]
# ## Example
#
# ```python
# data = [
#     {"id": 1, "email": "test@test.com"},
#     {"id": 2, "email": None},
#     {"id": 3, "email": "invalid-email"}
# ]
# ```

# %% [markdown]
# ## Practice
#
# - Identify bad records
# - Print invalid rows

# %% [markdown]
# ## Assignment
#
# Using the sample `data`, separate records into valid and invalid groups, and explain why each invalid row failed.

# %% [markdown]
# ## Interview Questions
#
# 1. Why is data quality important in pipelines?
# 2. What are common data quality issues?
# 3. How do you detect invalid records?
# 4. How do you prevent bad data from reaching analytics?

# %% [markdown]
# ## Your tasks
#
# - [ ] Run the sample and list invalid rows.
# - [ ] Write one rule each for missing, duplicate, and invalid-format detection.
# - [ ] Summarize why data validation belongs before load.
