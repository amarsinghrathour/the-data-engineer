# %% [markdown]
# # Validation and Data Quality Checks

# %% [markdown]
# ## Validation Functions
#
# ```python
# def validate_email(email):
#     return "@" in email if email else False
#
# def validate_record(d):
#     if not d.get("id"):
#         return False
#     if not validate_email(d.get("email")):
#         return False
#     return True
# ```

# %% [markdown]
# ## Apply Validation
#
# ```python
# valid = []
# invalid = []
#
# for d in data:
#     if validate_record(d):
#         valid.append(d)
#     else:
#         invalid.append(d)
#
# print("Valid:", valid)
# print("Invalid:", invalid)
# ```

# %% [markdown]
# ## Add Logging
#
# ```python
# import logging
#
# logging.basicConfig(filename="dq.log", level=logging.INFO)
# logging.info(f"Invalid records: {invalid}")
# ```

# %% [markdown]
# ## Practice
#
# 1. Add phone-number validation.
# 2. Add duplicate-ID detection.
# 3. Log both total invalid count and invalid records.

# %% [markdown]
# ## Assignment
#
# Build a reusable `validate_record()` function for your ETL payload and output `valid` / `invalid` sets with logs.

# %% [markdown]
# ## Interview Questions
#
# 1. How do you design validation checks?
# 2. What should be logged for invalid data?
# 3. How do you handle partial data quality failures?
# 4. Where should validation happen in ETL?

# %% [markdown]
# ## Your tasks
#
# - [ ] Implement `validate_record()` for at least 3 rules.
# - [ ] Split records into `valid` and `invalid` outputs.
# - [ ] Write invalid records to `dq.log`.
